# %% [markdown]
# Скриптна обрада података служи за аутоматску обраду велике количине података, али је применљива и у једноставнијим случајевима. У овим задацима су дати примери скупова података са једноставном структуром које треба обрадити у Пајтону користећи Џупитер окружење.

# %% [markdown]
# # Први задатак - Повезивање података

# %% [markdown]
# Слично као код трећег задатка у Екселу, сада треба урадити повезивање података у Пајтону. На основу података о просечним зарадама које смо сачували у фајлу "03IND01.csv" и података о статистичким регионима и областима (фајл "Statistički_šifarnik.csv") сада треба да утврдите колике су просечне зараде по регионима. У повезаној табели би требало да имате податке о региону, области, општини итд. из првог задатка и податке о зарадама из друге табеле.
#
# Ваш задатак је да израчунате просечне нето зараде по статистичким регионима у Србији. Резултате прикажите као табелу и као стубични дијаграм (eng. _bar chart_).
#
# Помоћ:
#
# - Користите функцију `merge` из __pandas__ библиотеке.
# - За цртање дијаграма користите `bar` из __matplotlib.pyplot__ или __plotly.express__ библиотека.

# %% [markdown]
# # Други задатак - Анализа података о јавним конкурсима

# %% [markdown]
# Подаци о раду локалних самоуправа су посебно интересантни цивилном сектору. У оквиру пројекта ["Јавно о јавним конкурсима"](https://birnsrbija.rs/javno-o-javnim-konkursima/) објављена је до сада највећа база које обједињава јавно доступне податке о јавним конкурсима. Осим самих података у CSV формату, на сајту је дат и детаљан опис свих атрибута са извештајем и анализом правног оквира.
#
# Ваш задатак је да:
# - учитате табелу из CSV фајла,
# - анализирате податке и утврдите која је област (сектор) била приоритет за финансирање и дате образложење критеријума који сте користили да то утврдите,
# - утврдите која је организација добила највише пројеката и колико их је било,
# - утврдите колико је било пројеката који су финансирани иако нису имали назив пројекта и
# - утврдите колико је било конкурса који су реализовани иако објава конкурса није била доступна на сајту органа који је расписао јавни конкурс.
